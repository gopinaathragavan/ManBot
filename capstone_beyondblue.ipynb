# %% [markdown]
# # Capstone

# %% [markdown]
# # <u>Executive Summary</u>
#
# ### What is your goal?
#
# * My long-term goal is to build a chatbot for the domain of domestic violence/mental health. It will act as a friend and check in with you at least weekly. During the conversation, it will monitor the sentiment of the user during a conversation and also monitor for risk factors that indicate the need to trigger early intervention and referral to a human before stigma arises
# * We have split the project into phases:
#     * Phase 1 (capstone goal): Scraping Data from 1 forum, EDA including preliminary Topic Modelling and Sentiment Analysis
#     * Phase 2: Increase dataset size and rerun tasks in phase 1
#     * Phase 3: Introduce subject matter experts and continue to fine-tune models. Increase dataset to have enough data to create different recurrent neural networks such as LSTM and GRUs that handle vanishing/exploding gradient well.
#     * Phase 4: Refine model for deployment to incorporate it into the chatbot
#
# The remainder of this report and executive summary will be written in the context of reporting on preliminary findings for Phase 1.
#
# ### What are your metrics?
#
# * The metrics or key success factors have been split separately for scraping, topic modelling and sentiment analysis:
#     * Scraping: successfully scraped 1 conversational thread in the depression sub-forum of beyondblue
#     * Topic Modelling using LDA: Accurate identification of distinct topics in beyondblue mental health forum. Topics should not have considerable overlapping of words across other topics
#     * Sentiment Analysis: Extract the overall sentiment of postings in beyondblue and individual sentiment of each posting in the sub-forum
#
# ### What were your findings?
#
# Based on the word phrases from the topic models and visual examination of the posts, we can see that the forum has users that provide a lot of positive reinforcement and people who are empathetic towards the users coming in a state of depression. Therefore, there is hardly any negative sentiment in the post and overall sentiment is neutral to positive. This would be the general sentiment that a normal counsellor would express towards a person who is seeking counsel from a state of depression.
#
# Common risk factors in terms of topics were inconclusive using LDA and we will be exploring better algorithms such as latent semantic analysis to detect more meaningful topics. LDA was a good initial model to get a high-level understanding of the frequently used terms by users in the forum.
#
# ### What risks/limitations/assumptions affect these findings?
#
# Due to time constraints, the models that have been selected for the first iteration were simple models to extract preliminary findings to see what topics we are getting from LDA and also what the sentiment of postings are.
#
# During EDA, stopwords list was extended with pronouns manually based on visual examination. This will not scale well when adding new data in the next iteration so in the next iteration, we will be implementing part of speech tagging to overcome this current limitation.
#
# Manually evaluating the sentiment analysis will be time-consuming for future iterations and this is a limitation to scalability that we seek to address in future iterations.

# %% [markdown]
# # 1 SCRAPING DATA

# %%
#General imports
import numpy as np
import pandas as pd
import math
from decimal import Decimal
import re
import string

# webscraping and related imports
import requests
import bs4
from bs4 import BeautifulSoup
import time

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 1.1 Beautiful Soup scraping

# %%
url = "https://www.beyondblue.org.au/get-support/online-forums/depression/depression-fight-it-or-embrace-it-"
#conducting a request of the stated URL above:
response = requests.get(url)

# You can use status codes to understand how the target server responds to your request.
#Ex. 200 = OK, 400 = Bad Request, 403 = Forbidden, 404 = Not Found
print('Status Code: ',response.status_code)

#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(response.text, "lxml")
#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# Status Code:  200
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie10 lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie10 lt-ie9" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head id="Head1">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="beyondblue" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.beyondblue.org.au/App_Themes/standard/images/BB_FB_logo.png" property="og:image"/>
#   <title>
#    DEPRESSION: Fight it or embrace it?
#   </title>
#   <!-- Default = user scalable, no responsive -->
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <!-- modernizr -->
#   <script data-dtconfig="rid=RID_-442769491|rpid=-1599973489|domain=beyondblue.org.au|reportUrl=/rb_bf70636nae|featureHash=2fjqrx|lastModification=1525672835824|dtVersion=10139180201161915|tp=500,50,0,1|agentUri=/ruxitagentjs_2fjqrx_10139180201161915.js" src="/ruxitagentjs_2fjqrx_10139180201161915.js" type="text/javascript">
#   </script>
#   <script src=" /App_Themes/standard/scripts/libs/jquery-1.8.3.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/standard/scripts/libs/modernizr-2.5.3.min.js" type="text/javascript">
#   </script>
#   <!-- Fonts -->
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:300italic,700italic,400,300,600,700" rel="stylesheet" type="text/css"/>
#   <!-- styles -->
#   <!--<link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" />-->
#   <link href="/App_Themes/standard/styles/reset.css?v=20150319" rel="stylesheet"/>
#   <!--[if (lt IE 9) & (!IEMobile)]>
# 			    <link rel="stylesheet" href="/App_Themes/Standard/styles/desktopOnly.css?v=20150319" />
# 		    <![endif]-->
#   <!--[if (gte IE 9) | (IEMobile)]><!-->
#   <!--<link rel="stylesheet" href="/App_Themes/standard/styles/mobileFirst.css?v=20150319" />-->
#   <link href="/App_Themes/reskin/main.css?v=20180405" media="screen" rel="stylesheet"/>
#   <!--<![endif]-->
#   <link href="/App_Themes/reskin/print.css" media="print" rel="stylesheet"/>
#   <!--<link rel="stylesheet" href="/App_Themes/standard/styles/print.css?v=20150319" media="print" />-->
#   <link href="/App_Themes/global/styles/global.css?v=20150319" rel="stylesheet"/>
#   <!-- html5Shiv for IE8 purposes -->
#   <!--[if lt IE 9]><script src="/App_Themes/standard/scripts/libs/html5shiv.js"></script><![endif]-->
#   <!--[if lt IE 9]><script src="/App_Themes/standard/scripts/libs/html5shiv-printshiv.js"></script><![endif]-->
#   <!-- jquery UI -->
#   <link href="/App_Themes/Standard/scripts/libs/jquery-ui.css" rel="stylesheet"/>
#   <script type="text/javascript">
#    dataLayer = [];
#   </script>
#   <link class="Telerik_stylesheet" href="https://d35islomi5rx1v.cloudfront.net/ajax/2017.2.621/Menu.css" rel="stylesheet" type="text/css"/>
#   <link class="Telerik_stylesheet" href="https://d35islomi5rx1v.cloudfront.net/ajax/2017.2.621/Default/Menu.Default.css" rel="stylesheet" type="text/css"/>
#   <meta content="Sitefinity 10.1.6524.0 PU" name="Generator"/>
#   <link href="/Telerik.Web.UI.WebResource.axd?d=aIimNus_HvMjniOwcn2bHjBS-NbcYx6YXIvumntf_qUnmaaBzqyg-CJ3OwQteFxARqRHe0JcC-ytceq5BYWKhW67jLioJTjwMFxtfD283NhroqsSQFz263exDH23nYibJIljvtm5TG8JBV6X2LWxaw2&amp;t=636538188012511107&amp;compress=0&amp;_TSM_CombinedScripts_=%3b%3bTelerik.Sitefinity.Resources%2c+Version%3d10.1.6524.0%2c+Culture%3dneutral%2c+PublicKeyToken%3db28c218413bdf563%3aen%3a75b5abc1-9d3d-447e-a99c-02d926fde5df%3ac1bd62cb%3ab6439d72%3a7a6c1bf7%3a7a90d6a%3a2380cb54" rel="stylesheet" type="text/css"/>
#   <style media="all" type="text/css">
#    .sfPostQuoteView {
#   font-size: 1em;
#   font-style: italic;
# }
#   </style>
#  </head>
#  <body class="beyondBlue pageID-69478fed-f42c-4faa-8005-d4f28e20c179 parentID-c81c9bcc-2fe3-4fcf-99e9-4b5339d7644f templateID-164178e8-293c-4cab-a404-c9549c97324b rootNodeId-c81c9bcc-2fe3-4fcf-99e9-4b5339d7644f siteID-d74d1632-aab2-4dfb-92bf-9524d3a13fd6" id="body">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W4C7HQ" style="display: none; visibility: hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function (w, d, s, l, i) {
#     w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#     }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-W4C7HQ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <form action="./depression-fight-it-or-embrace-it-" id="form1" method="post">
#    <input id="ctl17_TSSM" name="ctl17_TSSM" type="hidden" value=""/>
#    <input id="__VIEWSTATEFIELDCOUNT" name="__VIEWSTATEFIELDCOUNT" type="hidden" value="286"/>
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    <input id="__VIEWSTATE1" name="__VIEWSTATE1" type="hidden" value="..."/>
#    <input id="__VIEWSTATE2" name="__VIEWSTATE2" type="hidden" value="..."/>
#    <input id="__VIEWSTATE3" name="__VIEWSTATE3" type="hidden" value="..."/>
#    <input id="__VIEWSTATE4" name="__VIEWSTATE4" type="hidden" value="..."/>
#    <input id="__VIEWSTATE5" name="__VIEWSTATE5" type="hidden" value="..."/>
#    <input id="__VIEWSTATE6" name="__VIEWSTATE6" type="hidden" value="..."/>
#    <input id="__VIEWSTATE7" name="__VIEWSTATE7" type="hidden" value="..."/>
#    <input id="__VIEWSTATE8" name="__VIEWSTATE8" type="hidden" value="..."/>
#    <input id="__VIEWSTATE9" name="__VIEWSTATE9" type="hidden" value="..."/>
#    <input id="__VIEWSTATE10" name="__VIEWSTATE10" type="hidden" value="..."/>
#    <input id="__VIEWSTATE11" name="__VIEWSTATE11" type="hidden" value="..."/>
#    <input id="__VIEWSTATE12" name="__VIEWSTATE12" type="hidden" value="..."/>
#    <input id="__VIEWSTATE13" name="__VIEWSTATE13" type="hidden" value="..."/>
#    <input id="__VIEWSTATE14" name="__VIEWSTATE14" type="hidden" value="..."/>
#    <input id="__VIEWSTATE15" name="__VIEWSTATE15" type="hidden" value="..."/>
#    <input id="__VIEWSTATE16" name="__VIEWSTATE16" type="hidden" value="..."/>
#    <input id="__VIEWSTATE17" name="__VIEWSTATE17" type="hidden" value="..."/>
#    <input id="__VIEWSTATE18" name="__VIEWSTATE18" type="hidden" value="..."/>
#    <input id="__VIEWSTATE19" name="__VIEWSTATE19" type="hidden" value="..."/>
#    <input id="__VIEWSTATE20" name="__VIEWSTATE20" type="hidden" value="..."/>
#    <input id="__VIEWSTATE21" name="__VIEWSTATE21" type="hidden" value="..."/>
#    <input id="__VIEWSTATE22" name="__VIEWSTATE22" type="hidden" value="..."/>
#    <input id="__VIEWSTATE23" name="__VIEWSTATE23" type="hidden" value="..."/>
#    <input id="__VIEWSTATE24" name="__VIEWSTATE24" type="hidden" value="..."/>
#    <input id="__VIEWSTATE25" name="__VIEWSTATE25" type="hidden" value="..."/>
#    <input id="__VIEWSTATE26" name="__VIEWSTATE26" type="hidden" value="..."/>
#    <input id="__VIEWSTATE27" name="__VIEWSTATE27" type="hidden" value="..."/>
#    <input id="__VIEWSTATE28" name="__VIEWSTATE28" type="hidden" value="..."/>
#    <input id="__VIEWSTATE29" name="__VIEWSTATE29" type="hidden" value="..."/>
#    <input id="__VIEWSTATE30" name="__VIEWSTATE30" type="hidden" value="..."/>
#    <input id="__VIEWSTATE31" name="__VIEWSTATE31" type="hidden" value="..."/>
#    <input id="__VIEWSTATE32" name="__VIEWSTATE32" type="hidden" value="..."/>
#    <input id="__VIEWSTATE33" name="__VIEWSTATE33" type="hidden" value="..."/>
#    <input id="__VIEWSTATE34" name="__VIEWSTATE34" type="hidden" value="..."/>
#    <input id="__VIEWSTATE35" name="__VIEWSTATE35" type="hidden" value="..."/>
#    <input id="__VIEWSTATE36" name="__VIEWSTATE36" type="hidden" value="..."/>
#    <input id="__VIEWSTATE37" name="__VIEWSTATE37" type="hidden" value="..."/>
#    <input id="__VIEWSTATE38" name="__VIEWSTATE38" type="hidden" value="..."/>
#    <input id="__VIEWSTATE39" name="__VIEWSTATE39" type="hidden" value="..."/>
#    <input id="__VIEWSTATE40" name="__VIEWSTATE40" type="hidden" value="..."/>
#    <input id="__VIEWSTATE41" name="__VIEWSTATE41" type="hidden" value="..."/>
#    <input id="__VIEWSTATE42" name="__VIEWSTATE42" type="hidden" value="..."/>
#    <input id="__VIEWSTATE43" name="__VIEWSTATE43" type="hidden" value="..."/>
#    <input id="__VIEWSTATE44" name="__VIEWSTATE44" type="hidden" value="..."/>
#    <input id="__VIEWSTATE45" name="__VIEWSTATE45" type="hidden" value="..."/>
#    <input id="__VIEWSTATE46" name="__VIEWSTATE46" type="hidden" value="..."/>
#    <input id="__VIEWSTATE47" name="__VIEWSTATE47" type="hidden" value="..."/>
#    <input id="__VIEWSTATE48" name="__VIEWSTATE48" type="hidden" value="..."/>
#    <input id="__VIEWSTATE49" name="__VIEWSTATE49" type="hidden" value="..."/>
#    <input id="__VIEWSTATE50" name="__VIEWSTATE50" type="hidden" value="..."/>
#    <input id="__VIEWSTATE51" name="__VIEWSTATE51" type="hidden" value="..."/>
#    <input id="__VIEWSTATE52" name="__VIEWSTATE52" type="hidden" value="..."/>
#    <input id="__VIEWSTATE53" name="__VIEWSTATE53" type="hidden" value="..."/>
#    <input id="__VIEWSTATE54" name="__VIEWSTATE54" type="hidden" value="..."/>
#    <input id="__VIEWSTATE55" name="__VIEWSTATE55" type="hidden" value="..."/>
#    <input id="__VIEWSTATE56" name="__VIEWSTATE56" type="hidden" value="..."/>
#    <input id="__VIEWSTATE57" name="__VIEWSTATE57" type="hidden" value="..."/>
#    <input id="__VIEWSTATE58" name="__VIEWSTATE58" type="hidden" value="..."/>
#    <input id="__VIEWSTATE59" name="__VIEWSTATE59" type="hidden" value="..."/>
#    <input id="__VIEWSTATE60" name="__VIEWSTATE60" type="hidden" value="..."/>
#    <input id="__VIEWSTATE61" name="__VIEWSTATE61" type="hidden" value="..."/>
#    <input id="__VIEWSTATE62" name="__VIEWSTATE62" type="hidden" value="..."/>
#    <input id="__VIEWSTATE63" name="__VIEWSTATE63" type="hidden" value="..."/>
#    <input id="__VIEWSTATE64" name="__VIEWSTATE64" type="hidden" value="..."/>
#    <input id="__VIEWSTATE65" name="__VIEWSTATE65" type="hidden" value="..."/>
#    <input id="__VIEWSTATE66" name="__VIEWSTATE66" type="hidden" value="..."/>
#    <input id="__VIEWSTATE67" name="__VIEWSTATE67" type="hidden" value="..."/>
#    <input id="__VIEWSTATE68" name="__VIEWSTATE68" type="hidden" value="..."/>
#    <input id="__VIEWSTATE69" name="__VIEWSTATE69" type="hidden" value="..."/>
#    <input id="__VIEWSTATE70" name="__VIEWSTATE70" type="hidden" value="..."/>
#    <input id="__VIEWSTATE71" name="__VIEWSTATE71" type="hidden" value="..."/>
#    <input id="__VIEWSTATE72" name="__VIEWSTATE72" type="hidden" value="..."/>
#    <input id="__VIEWSTATE73" name="__VIEWSTATE73" type="hidden" value="..."/>
#    <input id="__VIEWSTATE74" name="__VIEWSTATE74" type="hidden" value="..."/>
#    <input id="__VIEWSTATE75" name="__VIEWSTATE75" type="hidden" value="..."/>
#    <input id="__VIEWSTATE76" name="__VIEWSTATE76" type="hidden" value="..."/>
#    <input id="__VIEWSTATE77" name="__VIEWSTATE77" type="hidden" value="..."/>
#    <input id="__VIEWSTATE78" name="__VIEWSTATE78" type="hidden" value="..."/>
#    <input id="__VIEWSTATE79" name="__VIEWSTATE79" type="hidden" value="..."/>
#    <input id="__VIEWSTATE80" name="__VIEWSTATE80" type="hidden" value="..."/>
#    <input id="__VIEWSTATE81" name="__VIEWSTATE81" type="hidden" value="..."/>
#    <input id="__VIEWSTATE82" name="__VIEWSTATE82" type="hidden" value="..."/>
#    <input id="__VIEWSTATE83" name="__VIEWSTATE83" type="hidden" value="..."/>
#    <input id="__VIEWSTATE84" name="__VIEWSTATE84" type="hidden" value="..."/>
#    <input id="__VIEWSTATE85" name="__VIEWSTATE85" type="hidden" value="..."/>
#    <input id="__VIEWSTATE86" name="__VIEWSTATE86" type="hidden" value="..."/>
#    <input id="__VIEWSTATE87" name="__VIEWSTATE87" type="hidden" value="..."/>
#    <input id="__VIEWSTATE88" name="__VIEWSTATE88" type="hidden" value="..."/>
#    <input id="__VIEWSTATE89" name="__VIEWSTATE89" type="hidden" value="..."/>
#    <input id="__VIEWSTATE90" name="__VIEWSTATE90" type="hidden" value="..."/>
#    <input id="__VIEWSTATE91" name="__VIEWSTATE91" type="hidden" value="..."/>
#    <input id="__VIEWSTATE92" name="__VIEWSTATE92" type="hidden" value="..."/>
#    <input id="__VIEWSTATE93" name="__VIEWSTATE93" type="hidden" value="..."/>
#    <input id="__VIEWSTATE94" name="__VIEWSTATE94" type="hidden" value="..."/>
#    <input id="__VIEWSTATE95" name="__VIEWSTATE95" type="hidden" value="..."/>
#    <input id="__VIEWSTATE96" name="__VIEWSTATE96" type="hidden" value="..."/>
#    <input id="__VIEWSTATE97" name="__VIEWSTATE97" type="hidden" value="..."/>
#    <input id="__VIEWSTATE98" name="__VIEWSTATE98" type="hidden" value="..."/>
#    <input id="__VIEWSTATE99" name="__VIEWSTATE99" type="hidden" value="..."/>
#    <input id="__VIEWSTATE100" name="__VIEWSTATE100" type="hidden" value="..."/>
#    <input id="__VIEWSTATE101" name="__VIEWSTATE101" type="hidden" value="..."/>
#    <input id="__VIEWSTATE102" name="__VIEWSTATE102" type="hidden" value="..."/>
#    <input id="__VIEWSTATE103" name="__VIEWSTATE103" type="hidden" value="..."/>
#    <input id="__VIEWSTATE104" name="__VIEWSTATE104" type="hidden" value="..."/>
#    <input id="__VIEWSTATE105" name="__VIEWSTATE105" type="hidden" value="..."/>
#    <input id="__VIEWSTATE106" name="__VIEWSTATE106" type="hidden" value="..."/>
#    <input id="__VIEWSTATE107" name="__VIEWSTATE107" type="hidden" value="..."/>
#    <input id="__VIEWSTATE108" name="__VIEWSTATE108" type="hidden" value="..."/>
#    <input id="__VIEWSTATE109" name="__VIEWSTATE109" type="hidden" value="..."/>
#    <input id="__VIEWSTATE110" name="__VIEWSTATE110" type="hidden" value="..."/>
#    <input id="__VIEWSTATE111" name="__VIEWSTATE111" type="hidden" value="..."/>
#    <input id="__VIEWSTATE112" name="__VIEWSTATE112" type="hidden" value="..."/>
#    <input id="__VIEWSTATE113" name="__VIEWSTATE113" type="hidden" value="..."/>
#    <input id="__VIEWSTATE114" name="__VIEWSTATE114" type="hidden" value="..."/>
#    <input id="__VIEWSTATE115" name="__VIEWSTATE115" type="hidden" value="..."/>
#    <input id="__VIEWSTATE116" name="__VIEWSTATE116" type="hidden" value="..."/>
#    <input id="__VIEWSTATE117" name="__VIEWSTATE117" type="hidden" value="..."/>
#    <input id="__VIEWSTATE118" name="__VIEWSTATE118" type="hidden" value="..."/>
#    <input id="__VIEWSTATE119" name="__VIEWSTATE119" type="hidden" value="..."/>
#    <input id="__VIEWSTATE120" name="__VIEWSTATE120" type="hidden" value="..."/>
#    <input id="__VIEWSTATE121" name="__VIEWSTATE121" type="hidden" value="..."/>
#    <input id="__VIEWSTATE122" name="__VIEWSTATE122" type="hidden" value="..."/>
#    <input id="__VIEWSTATE123" name="__VIEWSTATE123" type="hidden" value="..."/>
#    <input id="__VIEWSTATE124" name="__VIEWSTATE124" type="hidden" value="..."/>
#    <input id="__VIEWSTATE125" name="__VIEWSTATE125" type="hidden" value="..."/>
#    <input id="__VIEWSTATE126" name="__VIEWSTATE126" type="hidden" value="..."/>
#    <input id="__VIEWSTATE127" name="__VIEWSTATE127" type="hidden" value="..."/>
#    <input id="__VIEWSTATE128" name="__VIEWSTATE128" type="hidden" value="..."/>
#    <input id="__VIEWSTATE129" name="__VIEWSTATE129" type="hidden" value="..."/>
#    <input id="__VIEWSTATE130" name="__VIEWSTATE130" type="hidden" value="..."/>
#    <input id="__VIEWSTATE131" name="__VIEWSTATE131" type="hidden" value="..."/>
#    <input id="__VIEWSTATE132" name="__VIEWSTATE132" type="hidden" value="..."/>
#    <input id="__VIEWSTATE133" name="__VIEWSTATE133" type="hidden" value="..."/>
#    <input id="__VIEWSTATE134" name="__VIEWSTATE134" type="hidden" value="..."/>
#    <input id="__VIEWSTATE135" name="__VIEWSTATE135" type="hidden" value="..."/>
#    <input id="__VIEWSTATE136" name="__VIEWSTATE136" type="hidden" value="..."/>
#    <input id="__VIEWSTATE137" name="__VIEWSTATE137" type="hidden" value="..."/>
#    <input id="__VIEWSTATE138" name="__VIEWSTATE138" type="hidden" value="..."/>
#    <input id="__VIEWSTATE139" name="__VIEWSTATE139" type="hidden" value="..."/>
#    <input id="__VIEWSTATE140" name="__VIEWSTATE140" type="hidden" value="..."/>
#    <input id="__VIEWSTATE141" name="__VIEWSTATE141" type="hidden" value="..."/>
#    <input id="__VIEWSTATE142" name="__VIEWSTATE142" type="hidden" value="..."/>
#    <input id="__VIEWSTATE143" name="__VIEWSTATE143" type="hidden" value="..."/>
#    <input id="__VIEWSTATE144" name="__VIEWSTATE144" type="hidden" value="..."/>
#    <input id="__VIEWSTATE145" name="__VIEWSTATE145" type="hidden" value="..."/>
#    <input id="__VIEWSTATE146" name="__VIEWSTATE146" type="hidden" value="..."/>
#    <input id="__VIEWSTATE147" name="__VIEWSTATE147" type="hidden" value="..."/>
#    <input id="__VIEWSTATE148" name="__VIEWSTATE148" type="hidden" value="..."/>
#    <input id="__VIEWSTATE149" name="__VIEWSTATE149" type="hidden" value="..."/>
#    <input id="__VIEWSTATE150" name="__VIEWSTATE150" type="hidden" value="..."/>
#    <input id="__VIEWSTATE151" name="__VIEWSTATE151" type="hidden" value="..."/>
#    <input id="__VIEWSTATE152" name="__VIEWSTATE152" type="hidden" value="..."/>
#    <input id="__VIEWSTATE153" name="__VIEWSTATE153" type="hidden" value="..."/>
#    <input id="__VIEWSTATE154" name="__VIEWSTATE154" type="hidden" value="..."/>
#    <input id="__VIEWSTATE155" name="__VIEWSTATE155" type="hidden" value="..."/>
#    <input id="__VIEWSTATE156" name="__VIEWSTATE156" type="hidden" value="..."/>
#    <input id="__VIEWSTATE157" name="__VIEWSTATE157" type="hidden" value="..."/>
#    <input id="__VIEWSTATE158" name="__VIEWSTATE158" type="hidden" value="..."/>
#    <input id="__VIEWSTATE159" name="__VIEWSTATE159" type="hidden" value="..."/>
#    <input id="__VIEWSTATE160" name="__VIEWSTATE160" type="hidden" value="..."/>
#    <input id="__VIEWSTATE161" name="__VIEWSTATE161" type="hidden" value="..."/>
#    <input id="__VIEWSTATE162" name="__VIEWSTATE162" type="hidden" value="..."/>
#    <input id="__VIEWSTATE163" name="__VIEWSTATE163" type="hidden" value="..."/>
#    <input id="__VIEWSTATE164" name="__VIEWSTATE164" type="hidden" value="..."/>
#    <input id="__VIEWSTATE165" name="__VIEWSTATE165" type="hidden" value="..."/>
#    <input id="__VIEWSTATE166" name="__VIEWSTATE166" type="hidden" value="..."/>
#    <input id="__VIEWSTATE167" name="__VIEWSTATE167" type="hidden" value="..."/>
#    <input id="__VIEWSTATE168" name="__VIEWSTATE168" type="hidden" value="..."/>
#    <input id="__VIEWSTATE169" name="__VIEWSTATE169" type="hidden" value="..."/>
#    <input id="__VIEWSTATE170" name="__VIEWSTATE170" type="hidden" value="..."/>
#    <input id="__VIEWSTATE171" name="__VIEWSTATE171" type="hidden" value="..."/>
#    <input id="__VIEWSTATE172" name="__VIEWSTATE172" type="hidden" value="..."/>
#    <input id="__VIEWSTATE173" name="__VIEWSTATE173" type="hidden" value="..."/>
#    <input id="__VIEWSTATE174" name="__VIEWSTATE174" type="hidden" value="..."/>
#    <input id="__VIEWSTATE175" name="__VIEWSTATE175" type="hidden" value="..."/>
#    <input id="__VIEWSTATE176" name="__VIEWSTATE176" type="hidden" value="..."/>
#    <input id="__VIEWSTATE177" name="__VIEWSTATE177" type="hidden" value="..."/>
#    <input id="__VIEWSTATE178" name="__VIEWSTATE178" type="hidden" value="..."/>
#    <input id="__VIEWSTATE179" name="__VIEWSTATE179" type="hidden" value="..."/>
#    <input id="__VIEWSTATE180" name="__VIEWSTATE180" type="hidden" value="..."/>
#    <input id="__VIEWSTATE181" name="__VIEWSTATE181" type="hidden" value="..."/>
#    <input id="__VIEWSTATE182" name="__VIEWSTATE182" type="hidden" value="..."/>
#    <input id="__VIEWSTATE183" name="__VIEWSTATE183" type="hidden" value="..."/>
#    <input id="__VIEWSTATE184" name="__VIEWSTATE184" type="hidden" value="..."/>
#    <input id="__VIEWSTATE185" name="__VIEWSTATE185" type="hidden" value="..."/>
#    <input id="__VIEWSTATE186" name="__VIEWSTATE186" type="hidden" value="..."/>
#    <input id="__VIEWSTATE187" name="__VIEWSTATE187" type="hidden" value="..."/>
#    <input id="__VIEWSTATE188" name="__VIEWSTATE188" type="hidden" value="..."/>
#    <input id="__VIEWSTATE189" name="__VIEWSTATE189" type="hidden" value="..."/>
#    <input id="__VIEWSTATE190" name="__VIEWSTATE190" type="hidden" value="..."/>
#    <input id="__VIEWSTATE191" name="__VIEWSTATE191" type="hidden" value="..."/>
#    <input id="__VIEWSTATE192" name="__VIEWSTATE192" type="hidden" value="..."/>
#    <input id="__VIEWSTATE193" name="__VIEWSTATE193" type="hidden" value="..."/>
#    <input id="__VIEWSTATE194" name="__VIEWSTATE194" type="hidden" value="..."/>
#    <input id="__VIEWSTATE195" name="__VIEWSTATE195" type="hidden" value="..."/>
#    <input id="__VIEWSTATE196" name="__VIEWSTATE196" type="hidden" value="..."/>
#    <input id="__VIEWSTATE197" name="__VIEWSTATE197" type="hidden" value="..."/>
#    <input id="__VIEWSTATE198" name="__VIEWSTATE198" type="hidden" value="..."/>
#    <input id="__VIEWSTATE199" name="__VIEWSTATE199" type="hidden" value="..."/>
#    <input id="__VIEWSTATE200" name="__VIEWSTATE200" type="hidden" value="..."/>
#    <input id="__VIEWSTATE201" name="__VIEWSTATE201" type="hidden" value="..."/>
#    <input id="__VIEWSTATE202" name="__VIEWSTATE202" type="hidden" value="..."/>
#    <input id="__VIEWSTATE203" name="__VIEWSTATE203" type="hidden" value="..."/>
#    <input id="__VIEWSTATE204" name="__VIEWSTATE204" type="hidden" value="..."/>
#    <input id="__VIEWSTATE205" name="__VIEWSTATE205" type="hidden" value="..."/>
#    <input id="__VIEWSTATE206" name="__VIEWSTATE206" type="hidden" value="..."/>
#    <input id="__VIEWSTATE207" name="__VIEWSTATE207" type="hidden" value="..."/>
#    <input id="__VIEWSTATE208" name="__VIEWSTATE208" type="hidden" value="..."/>
#    <input id="__VIEWSTATE209" name="__VIEWSTATE209" type="hidden" value="..."/>
#    <input id="__VIEWSTATE210" name="__VIEWSTATE210" type="hidden" value="..."/>
#    <input id="__VIEWSTATE211" name="__VIEWSTATE211" type="hidden" value="..."/>
#    <input id="__VIEWSTATE212" name="__VIEWSTATE212" type="hidden" value="..."/>
#    <input id="__VIEWSTATE213" name="__VIEWSTATE213" type="hidden" value="..."/>
#    <input id="__VIEWSTATE214" name="__VIEWSTATE214" type="hidden" value="..."/>
#    <input id="__VIEWSTATE215" name="__VIEWSTATE215" type="hidden" value="..."/>
#    <input id="__VIEWSTATE216" name="__VIEWSTATE216" type="hidden" value="..."/>
#    <input id="__VIEWSTATE217" name="__VIEWSTATE217" type="hidden" value="..."/>
#    <input id="__VIEWSTATE218" name="__VIEWSTATE218" type="hidden" value="..."/>
#    <input id="__VIEWSTATE219" name="__VIEWSTATE219" type="hidden" value="..."/>
#    <input id="__VIEWSTATE220" name="__VIEWSTATE220" type="hidden" value="..."/>
#    <input id="__VIEWSTATE221" name="__VIEWSTATE221" type="hidden" value="..."/>
#    <input id="__VIEWSTATE222" name="__VIEWSTATE222" type="hidden" value="..."/>
#    <input id="__VIEWSTATE223" name="__VIEWSTATE223" type="hidden" value="..."/>
#    <input id="__VIEWSTATE224" name="__VIEWSTATE224" type="hidden" value="..."/>
#    <input id="__VIEWSTATE225" name="__VIEWSTATE225" type="hidden" value="..."/>
#    <input id="__VIEWSTATE226" name="__VIEWSTATE226" type="hidden" value="..."/>
#    <input id="__VIEWSTATE227" name="__VIEWSTATE227" type="hidden" value="..."/>
#    <input id="__VIEWSTATE228" name="__VIEWSTATE228" type="hidden" value="..."/>
#    <input id="__VIEWSTATE229" name="__VIEWSTATE229" type="hidden" value="..."/>
#    <input id="__VIEWSTATE230" name="__VIEWSTATE230" type="hidden" value="..."/>
#    <input id="__VIEWSTATE231" name="__VIEWSTATE231" type="hidden" value="..."/>
#    <input id="__VIEWSTATE232" name="__VIEWSTATE232" type="hidden" value="..."/>
#    <input id="__VIEWSTATE233" name="__VIEWSTATE233" type="hidden" value="..."/>
#    <input id="__VIEWSTATE234" name="__VIEWSTATE234" type="hidden" value="..."/>
#    <input id="__VIEWSTATE235" name="__VIEWSTATE235" type="hidden" value="..."/>
#    <input id="__VIEWSTATE236" name="__VIEWSTATE236" type="hidden" value="..."/>
#    <input id="__VIEWSTATE237" name="__VIEWSTATE237" type="hidden" value="..."/>
#    <input id="__VIEWSTATE238" name="__VIEWSTATE238" type="hidden" value="..."/>
#    <input id="__VIEWSTATE239" name="__VIEWSTATE239" type="hidden" value="..."/>
#    <input id="__VIEWSTATE240" name="__VIEWSTATE240" type="hidden" value="..."/>
#    <input id="__VIEWSTATE241" name="__VIEWSTATE241" type="hidden" value="..."/>
#    <input id="__VIEWSTATE242" name="__VIEWSTATE242" type="hidden" value="..."/>
#    <input id="__VIEWSTATE243" name="__VIEWSTATE243" type="hidden" value="..."/>
#    <input id="__VIEWSTATE244" name="__VIEWSTATE244" type="hidden" value="..."/>
#    <input id="__VIEWSTATE245" name="__VIEWSTATE245" type="hidden" value="..."/>
#    <input id="__VIEWSTATE246" name="__VIEWSTATE246" type="hidden" value="..."/>
#    <input id="__VIEWSTATE247" name="__VIEWSTATE247" type="hidden" value="..."/>
#    <input id="__VIEWSTATE248" name="__VIEWSTATE248" type="hidden" value="..."/>
#    <input id="__VIEWSTATE249" name="__VIEWSTATE249" type="hidden" value="..."/>
#    <input id="__VIEWSTATE250" name="__VIEWSTATE250" type="hidden" value="..."/>
#    <input id="__VIEWSTATE251" name="__VIEWSTATE251" type="hidden" value="..."/>
#    <input id="__VIEWSTATE252" name="__VIEWSTATE252" type="hidden" value="..."/>
#    <input id="__VIEWSTATE253" name="__VIEWSTATE253" type="hidden" value="..."/>
#    <input id="__VIEWSTATE254" name="__VIEWSTATE254" type="hidden" value="..."/>
#    <input id="__VIEWSTATE255" name="__VIEWSTATE255" type="hidden" value="..."/>
#    <input id="__VIEWSTATE256" name="__VIEWSTATE256" type="hidden" value="..."/>
#    <input id="__VIEWSTATE257" name="__VIEWSTATE257" type="hidden" value="..."/>
#    <input id="__VIEWSTATE258" name="__VIEWSTATE258" type="hidden" value="..."/>
#    <input id="__VIEWSTATE259" name="__VIEWSTATE259" type="hidden" value="..."/>
#    <input id="__VIEWSTATE260" name="__VIEWSTATE260" type="hidden" value="..."/>
#    <input id="__VIEWSTATE261" name="__VIEWSTATE261" type="hidden" value="..."/>
#    <input id="__VIEWSTATE262" name="__VIEWSTATE262" type="hidden" value="..."/>
#    <input id="__VIEWSTATE263" name="__VIEWSTATE263" type="hidden" value="..."/>
#    <input id="__VIEWSTATE264" name="__VIEWSTATE264" type="hidden" value="..."/>
#    <input id="__VIEWSTATE265" name="__VIEWSTATE265" type="hidden" value="..."/>
#    <input id="__VIEWSTATE266" name="__VIEWSTATE266" type="hidden" value="..."/>
#    <input id="__VIEWSTATE267" name="__VIEWSTATE267" type="hidden" value="..."/>
#    <input id="__VIEWSTATE268" name="__VIEWSTATE268" type="hidden" value="..."/>
#    <input id="__VIEWSTATE269" name="__VIEWSTATE269" type="hidden" value="..."/>
#    <input id="__VIEWSTATE270" name="__VIEWSTATE270" type="hidden" value="..."/>
#    <input id="__VIEWSTATE271" name="__VIEWSTATE271" type="hidden" value="..."/>
#    <input id="__VIEWSTATE272" name="__VIEWSTATE272" type="hidden" value="..."/>
#    <input id="__VIEWSTATE273" name="__VIEWSTATE273" type="hidden" value="..."/>
#    <input id="__VIEWSTATE274" name="__VIEWSTATE274" type="hidden" value="..."/>
#    <input id="__VIEWSTATE275" name="__VIEWSTATE275" type="hidden" value="..."/>
#    <input id="__VIEWSTATE276" name="__VIEWSTATE276" type="hidden" value="..."/>
#    <input id="__VIEWSTATE277" name="__VIEWSTATE277" type="hidden" value="..."/>
#    <input id="__VIEWSTATE278" name="__VIEWSTATE278" type="hidden" value="..."/>
#    <input id="__VIEWSTATE279" name="__VIEWSTATE279" type="hidden" value="..."/>
#    <input id="__VIEWSTATE280" name="__VIEWSTATE280" type="hidden" value="..."/>
#    <input id="__VIEWSTATE281" name="__VIEWSTATE281" type="hidden" value="..."/>
#    <input id="__VIEWSTATE282" name="__VIEWSTATE282" type="hidden" value="..."/>
#    <input id="__VIEWSTATE283" name="__VIEWSTATE283" type="hidden" value="..."/>
#    <input id="__VIEWSTATE284" name="__VIEWSTATE284" type="hidden" value="..."/>
#    <input id="__VIEWSTATE285" name="__VIEWSTATE285" type="hidden" value=""/>
#    <script src="/WebResource.axd?d=U32qooJ0xq85UXBD2HSL9WUmQoNJXu0SgRujw2iVZynSsq8Mw70UE2EGwu3uNeDLuX705s48FPpqKbk9R9klb9K5oAtJAYS8JGqM6utWzLaUXUTmXsYx-WYbatM33I5SnhfELdL-6YdnFjMpPZ0UCCdB6YIZdcrgXIDnRz_mjyzoi30DdE_k5KFKP_1vK0S8e5HsECDkg_ZC75Z_TkF27iZFGjsjlzAetQwb331aXio1&amp;t=636415312400000000" type="text/javascript">
#    </script>
#    <script src="https://ajax.aspnetcdn.com/ajax/4.6/1/MicrosoftAjax.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# (window.Sys && Sys._Application && Sys.Observer)||document.write('<script type="text/javascript" src="/ScriptResource.axd?d=wJ_uMRJPsJkD8XAJCUO3ugOV8KeK21bZfewbbEER77mvitcPPJKumFAWznkZBTfjAoiyZBVRMdskT2at-0K2DBGdfKp32sdKQ7xEeA_a0SX7lVVbGEiN74F5XIlOsP_UgFqTdA3MXARm3nbQnf81-5C8TygjrctWFy1Vf0SC1qk1&t=3d6efc1f"><\/script>');//]]>
#    </script>
#    <script src="//code.jquery.com/jquery-1.12.1.min.js" type="text/javascript">
#    </script>
#    <script src="//code.jquery.com/jquery-migrate-1.2.1.min.js" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=IapnndsM_6TPgtWM3EPq08EZQGu-Dt93bz0lnq9iHdmMoy3xgdS3hTErXMAXKKV7q-AqUvcqZ7Gdv-pdULzP-hFiFoQ7VCZ4OUJv5qTHuIAAOsSRAZxTC6bG6bdTTc1YVR-4hMTNLxU3JDpzAavzDQ2&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=S4rW-oMzRSHuQBcqR6ErB4MFwtrUD6oSuQdnuJsvCtDOeDlYit8HjijaKKNJLgtU9apjbvmnE8RpMzZq0WSydu0LYuQya6AKfEmgiNFwhfQSC7tWlPpPEBZdvaDwfFRHZzn77C96uE-liqwfuNhIfg2&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="../../../Websilk/CustomControls/Security/LoginWidgetOverride/LoginWidgetOverride.js" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=zqUZAsUmTxVU3VYuiI3vTIefB21OTcoEOp8K3RpMGLVqUoJn0kn4C2cxfPqT_AHEPzD_iJcftFRROvC9UmEiqAzFK9B_UlRhMnz8SV6gGyXf5fyAHtX4RlSAuqNW88gNnsIBuOl_O8KWuzPmtF1seaqX8JiAEYkR7xQzQepC3q1iRD128A8sS48eIXCYmHXk0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=6TMkW4I8eN71nJau84qcwvvj6KYJpZyf0KC5qCg11Ve-MGK7ceMK2hP3uW9JelczJJNMihkZlwwZre12QRuKQxkBUXfSRHSB6W7VhlBHvrtYBvk6ZFgzYlEEyQK-gYKti3MqaB3eI7RbnofkmaD9tC8_DO-rqY5TccXD3cuWCfntM0NK7VzQHBh2gNBllMCT0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=g-k8OoVhQIQGy4mWdAkCYhBCc2nJRmabYLKBTUHTfUO4M1Uw0V-tyvIsZHW3-wB90QYFW8GS62APwVo6aJwsry2Znxd8L47AbNhfLhVxB7pyYG0a3x5vwjRuNBa7WhH1lSeeLnAnbHvrJ1gyrrzekD8UbMmNU31rjp7Hxw2SZvM1&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=HWqTo-EHpjsrxDaPXH_4ZynRotnBhhdRGNCDZi0i4FGzPgr4-MWL2A6Ef8yW6KwTb0eDbSD-CG4onOdTob3BAKbjvQArnWCOobygkQIzZA83T55nXFfWAERlegirqJb4xRro8Iw07-Odxny8J86a95JK035J3fIqoEVQRb1B4Z5cwGUBzIGFvVwwkY70yCqO0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=M-LF00L13K-6097NWpAcW0xjK7PlP7TM2INEBL2xF-znsSbBHb1dQBqlNDu9Gmw1LFp-gQ8SVnBmDIsQyb0Q8WfyURFvp-zKrTFcG0FtAmnP0XVP_6KyM2Pn5-hILok7CoDckDeHpLicm_7wS0gswy0_3I4UUldszrxRqX9XZZiMZSFQzT79YHMkufBNLh1f0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=0VOoor_XZP0nS9wpIeYGEbnlsIqJKeIb5BSWHTIpa_kXWAQrv9blAbVzBG5AKb988lxfD9Aqf0mE9ApjKEBw49qjvgsPkrJV7e0TWKRkgRmf0anynoB3n-aAaY-dTGLljrlVfQc_4jkP1u_QHjiC13LFyVWjbVBJiSTNZ2TDri9TSSHejApNMPrW0wJIeUIQ0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=Yuy2no5xiFBGxFTSOrev0TgEuxfPrw9moWr9b6xMXJ0zOOqjAqoCvy3czuiWxZlEQHITp1rxg2vrEfVOvyYFpncfb977O0eIbRo59iN25ZtFlX_zrVzu_6lsMx1EahzCC9a6THx6adG2IokA-btvutNfEUg4j-Lrg1c6IFLB0WgqNJPuxWG5G1Q4ffgcB9Z40&amp;t=ffffffffc6fe71b1" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=70oV7S30-hqYPUHkSzWr9wRjvoQ67MI0u9l-hlgaVRr6dIli8F_wD1-MdB39PPAACzIyQQjmSS3ZtKxbwe1Fq8Pd-jV9t5kkY5tpQ3lD-M14wS4IbeVSp0r9EGVRTocWJnL71EfyIhbibKYwEu1Hncjh8MYB6RkAinwS5IzFBbEj28R18pVSKQMorSdNuuNcs5BuVoXDU-4Vw14Phj92_A2&amp;t=ffffffffc6fe71b1" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=JFR6XdiLRQG8yhAqQeI7Aa8dbDyCAMmYGC4Jq61W8UKGq8HrfY798rlmC0Uho9vSWUOXM-6TSPkIcslTo9UGEJ-AaQQvSqXbcRuNnY3gP-DvMQTJblIM0bhGm47lnvbipYarZL6doU2BiS7F0z7MoNhjzq32FBRdCKbK7E-OSysbKCV58UQ_BlWosS7-JxmV0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=pncvqehGgPDCBUxdIQ4zdJRLeIsCNavM4wogavYuBKZP4G3P7yBg8t0mpgxKY6nmuFLZINe9ig3r5d8I2KDcWbRGXulIHdQ2hMQ-4XImY6Qn5lHD6sLREfHzXQJ_TE8lJEK9uNZR3F_j1OnlaNXMgEC-V1eEKbs26_zBRZUHA9VKZApJFRbsVn_fZs_4c-X20&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=LiimB8dropVEIK0rCKMxlSV83FhU4j37-1c8QERP67dGqLP1ki7pIDslFr3-OPhO5Kp0vEAasxJmyzY-eQ5QW5-_bYruTc5OInYdMpVDFto8wBohavmv4wq2_mWDQK0XHIOjeZsOXLbI-17fI9QR5G5QRAE7_JgmbWiS3wd8uJNHNvbKYypG3vULq4zQUKmu0&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=fmZqDo5RH-M4NfsLlo9nAFCA1nTficG72nRPwxoaxAEbLLFLGPDAPehbfCjyI-pDx6Esa1A8ouTUTwtZEVp0p0KKmzR1SjQ3Ywlnk3tlRcjBpdRy1j6DSQsZcFo7roddGrwnBsBjrRRS6iJZD8q6TA2&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=hzy9sXieBqtgWlWQaQK9Vml5HxDN9MpCv9anfclsqGFzPzCruXlD1hv_Hu2kvR8Hm3-lxCBPvFwDBMJkpkN8RZ1Ku0emQA4wzYJtST-ck5vcfVjXpTneq5JFXFm1oKmUd_qw1DGi1u73dEnynEA1tw2&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=Rpv37zG_z37o_WYCHAkj0ubtciihnWKqUbFtv4CFLDGd0xtFOtqCnFuxFW0zsXllMroCHLsZ0jYmlQCj4i4QjIBevT1u66e3Yc29XX2a0aJZPNxxVPd6U5VGW5gxZpG7YVPOZnJU2RUoS4Yohy3PwWB9GeS2l2WvyflPO8aXSgY1&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=dFT0ajJAbxybaue4sK0R_2yhNkWBq-HSwhV3gCPJREjqv59feBnm37i77_34fuMUFqw7hvjLL4jZ6k5tlCldqTJygi0H7P2XGEEvfTZdGfzMsIIWPoWXdkf7r9YfsqmUjXaaIKQ0YppmWKif9a_kE4S9FyN8Y9U1ITlCdcxurn81&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=YIVHEz30LRoXxtyQeP393zu0wGPXzXMdU5YgWMlxSuvFh6mwXvde_2khrCqk4_edGkJ4dZP53NQUpLLtyIn7vVWbgXz27ocfmnpmW3U3ockxzx9Pd4jI5FNHYdunIXjPx1a_E_Rls3z5TU8Pobwv0MAdYJb_2lNcaNR-EB3wMQOnx_hv_TL0hR6RTyPVJ0Fw0&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=geeCzbIuguYCH456LHd06t9bwrlGKwOBhVkY8PoEvyUrl8quiOC1A5KbTeaPzJsdwC90a36k0ioiFRHN5mNQFqsl_LOu_BTxMBdI_VO9zdy1c2HCRSR7jIQohSggTMt1I4109Tc0T8vy3sBHqLDlAs0n03-tmIRzkLRT-uFetKU1&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=QwqbB1PTAc9rgaNRp1QGNGEJ-kDevTp1245IjZQWuU9OoQrZyXWwAd15SUG9GzVlP3umDXpWLcisgMzi5q0915icopSVfKvadQ6jmLNqlchOdTBw812hhwVef3LP18IOdiJOIYh80zBmuCZzlqQGr0Gyjc6Cidos5Pyc19XCwP01&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=qgz_BIYjWTeI7MiIwVA21VqzWdqRrxWv9q_tl6_q_a2Ij81-Uvs7wiqzZlLhw08aZwhLQ7vw7aFn6ICG6OxX4wbJlpuXlAH8OTbLnKgzLd_Ah6doShlxEV5pkRR-UvvB1KchzwInm9DVaQVwDCVPbw2&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=6wxDpRyvYCV8N70mAIuoUsRMXbJnvO47dI29zXORrWLmL3ehUQKnPaCu8TKoAcAZq58PakXQhjL4-TvXcSa2IRXV7CJesPpSjUUgkec_5SrALwsdv5-04S3-8mtkeUOeKFwYGba94XZoia-qR45zCyF28FwD4HANmQ5CzGCk5UQ1&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=0q78UptVwtHkTgI1EzwXMLuDok1ZoYOEMd2XOkxcZmizu-xgqKD_4G0iToyqLC7wt3cDOMBfFdTntrn-kqNDM3RIzvbioP3JMIpJXBFnatLJEPpgsHCKovO6KMTvdf3xxvy9z6Nu56eDu8J4k5kabjAGGu9s8WeAGAZrKFzk0GE1&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=8hVJlke-x3HPmK7Pil_XpIwyyiK7RwqnofyY1SztHYLdaSxYMvv9jXD6kmV04TCRfjSN-mLJ4T9DAa2xP3wEG5pnBXxoO4YVHCQ6_tBnaITZAFwjs4FULEbe2hKz5Jq3LSXBueTc772fWKQp8hzvB3eHcNHJV4adf2nIkfWblUXZ2lfqSfbcrZmPi-PPM72B0&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=zl7ZcRpk4RGGa00wwV82AdKDhUuvVNTDJ5GE-YUXcvgEkS0Nf9GL-mgJDYTlbNHkTjaSrjnMFUGj_P8LLCr_YwMzBMWKpbEtaN3OMMwA2y-92PyG7ZgCI_q0mMwt6GDEFLrTmFDG_0xaC84YglALgmRAqGGEBrwnC2EOzbUSVIZkLVVVPIIeKP68i6WfByBS0&amp;t=ffffffffc29634a9" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=jxyJDxSkb5S9TQYlLXLeRAuUebuLYOOuHow4bmFCcZhrwtK8dm4VTeNAhGV9Eg9UgAcrEMr7DCTzcKlz24fXvn-XQKk0djxN3YdGdYnDhsyaID44rY-TO2izvRSrHeUh3sQ9VIlkOAmtR3poD3UosBmS0XANC24n0RvlJzzyD-81&amp;t=154d5dcf" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=UvdFmzyZJbgShNUgw4qr-YjScmZjSPNod45docgJtf4Rf6F6sS-ndpeEAiUMPqVZAEH_k54p7k4OuCAP6lF7T4bTmwmdk1IPSu8oCERHMtOwoe_LPHYHOhGKpv6E_PaJgolXaPJ3dyylcoGA5KmvJ18HdSjTsZchlpADXcwJmT8tLZ_T_hI86JEHPv2iObIIQgLa8xe1F8s_gkz8F9QTTQ2&amp;t=ffffffffc29634a9" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=jeOn9Uib-LuI0wmUp1icXzK9hTGjg7eDHJYMh1a8LZyY1YR8HkELHMOIOmb01vMR3c0qsvVWmejCvbFN_mwa5LkTzw2WYAp9K-u6mq2lZMFozG6uJ0mqoB_qvRVqEz4A77cSY89-Nr9wxir5NaOGEBFsc6T03K7T798foHseAvc1&amp;t=35e1180d" type="text/javascript">
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="9447855F"/>
#    <input id="__VIEWSTATEENCRYPTED" name="__VIEWSTATEENCRYPTED" type="hidden" value=""/>
#    <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
#    <!-- 2017.2.621.40 -->
#    <div id="rajaxManager1SU">
#     <span id="ctl00_rajaxManager1" style="display:none;">
#     </span>
#    </div>
#    <script src="/App_Themes/standard/scripts/sysinit.js?v=20150319" type="text/javascript">
#    </script>
#    <header id="hd">
#     <div class="pgWidth">
#      <div class="sf_cols container">
#       <div class="sf_colsOut " style="">
#        <div class="sf_colsIn sf_1col_1in_100" id="HeaderPlaceholder_T22B85045090_Col00">
#         <div class="sf_cols header-split">
#          <div class="sf_colsOut sf_2cols_1_50" style="width: 26%;">
#           <div class="sf_colsIn sf_2cols_1in_33" id="HeaderPlaceholder_T22B85045023_Col00">
#            <div class="skipTo">
#             <a href="#content" id="skipToContent">
#              skip to content
#             </a>
#             <a href="#secondNav" id="skipToNav">
#              skip to secondary navigation
#             </a>
#            </div>
#            <div class="logo">
#             <a href="/">
#              <img alt="beyondblue. Depression, Anxiety - logo" class="display-desktop" src="/app_themes/reskin/images/bb-logo.png"/>
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="sf_colsOut sf_2cols_2_50" style="width: 74%;">
#           <div class="sf_colsIn sf_2cols_2in_67" id="HeaderPlaceholder_T22B85045023_Col01">
#            <div class="sf_cols header-split-right">
#             <div class="sf_colsOut sf_2cols_1_50" style="width: 57%;">
#              <div class="sf_colsIn sf_2cols_1in_50" id="HeaderPlaceholder_T22B85045009_Col00">
#               <div class="searchForm--header">
#                <label class="offScreen">
#                 Search
#                </label>
#                <input id="HeaderPlaceholder_T22B85045077_txt_Keyword" name="ctl00$HeaderPlaceholder$T22B85045077$txt_Keyword" placeholder="Search" type="text"/>
#                <button class="button button-icon" id="lb_Search" type="submit">
#                 <i class="fa fa-search">
#                 </i>
#                 <span class="offScreen">
#                  Search
#                 </span>
#                </button>
#               </div>
#               <script type="text/javascript">
#                $(function () {
#         $(".searchForm--header input").keypress(function (e) {
#             if (e.keyCode === 13) {
#                 return GlobalSearch();
#             }
#         });
#
#         $(".searchForm--header .button").click(function (e) {
#             return GlobalSearch();
#         });
#     });
#
#     function GlobalSearch() {
#         var keyword = $("#" + 'HeaderPlaceholder_T22B85045077_txt_Keyword').val();
#
#         location.href = '/general/search-results?keywords={{keyword}}'.replace('{{keyword}}', keyword);
#
#         return false;
#     }
#               </script>
#               <div class=" header-title">
#                <h2>
#                 <em>
#                  beyondblue
#                 </em>
#                 Support Service
#                </h2>
#                <div class="sub-title">
#                 Support. Advice. Action
#                </div>
#                <div class="header-title-phone">
#                 <span class="header-phone">
#                 </span>
#                 1300 22 4636
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="sf_colsOut sf_2cols_2_50" style="width: 43%;">
#              <div class="sf_colsIn sf_2cols_2in_50" id="HeaderPlaceholder_T22B85045009_Col01">
#               <div class=" ">
#                <ul class="contactList">
#                 <li>
#                  <span class="header-phone">
#                   <em class="fa fa-phone color-yellow">
#                   </em>
#                   1300 22 4636
#                  </span>
#                 </li>
#                 <li>
#                  <a href="https://online.beyondblue.org.au/Webmodules/chat/InitialInformation.aspx" id="support-link-top" onclick="dataLayer.push({'event': 'chatcontact-click'});" target="blank">
#                   <em class="fa fa-comments color-yellow">
#                   </em>
#                   Chat online
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://online.beyondblue.org.au/WebModules/Email/InitialInformation.aspx" id="support-link-top2" onclick="dataLayer.push({'event': 'emailcontact-click'});" target="blank">
#                   <em class="fa fa-envelope color-yellow ">
#                   </em>
#                   Email us
#                  </a>
#                 </li>
#                 <li>
#                  <em class="fa fa-users">
#                  </em>
#                  <a href="/get-support/online-forums" onclick="dataLayer.push({'event':'Campaigns', 'action':'Healthy Families', 'label':'Link - Online forums (header)'});return true;">
#                   Online forums
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <style>
#                .overridedisplay { display:none!important; }
#               </style>
#               <div class="form-login-shell">
#                <div class="cr43-logIn">
#                 <div class="loggedIn rmSlide loggedInPnl" id="pnlLoggedIn" style="display: none">
#                  <div class="loggedInContent">
#                   <a class="login-my-account" href="javascript:void(0);">
#                    my profile
#                   </a>
#                   <div class="blueVoices" id="bvLinkContainer">
#                    <em class="fa fa-tint">
#                    </em>
#                    <a href="https://www.beyondblue.org.au/bluevoices-community/bluevoices-home" id="HeaderPlaceholder_T22B85045062_hlBlueVoices">
#                     blueVoices
#                    </a>
#                   </div>
#                   <ul class="accountLinks">
#                    <li>
#                     <a href="https://www.beyondblue.org.au/members/member-profile" id="HeaderPlaceholder_T22B85045062_hlMyAccount">
#                      my account
#                     </a>
#                    </li>
#                    <li>
#                     <a class="logOut" href="/Sitefinity/SignOut?sts_signout=true&amp;redirect_uri=">
#                      log out
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </div>
#                 <div class="loggedOut loggedOutPnl" id="pnlLoggedOut" style="display: none">
#                  <a class="join-forum-header" href="/connect-with-others/online-forums">
#                   Join forum
#                  </a>
#                  <div class="loggedOutContent">
#                   <div class="menuLogin rmSlide">
#                    <div class="rmVertical">
#                     <a class="text-register" href="https://www.beyondblue.org.au/get-support/online-forums/sign-up" id="HeaderPlaceholder_T22B85045062_linkJoin">
#                      Register
#                     </a>
#                     <a class="loginLink" href="/get-support/online-forums/login" id="HeaderPlaceholder_T22B85045062_hlLogin">
#                      Login
#                     </a>
#                     <div class="menuLoginDivider">
#                      or
#                     </div>
#                     <a class="js_loginToggle text-login" href="javascript:void(0);">
#                      Login
#                      <span class="offScreen" id="toggleStateText">
#                       show
#                      </span>
#                     </a>
#                     <div class="loginWhole">
#                      <div class="loginExtraWrap">
#                       <h2 class="offScreen">
#                        Login
#                       </h2>
#                       <div class="display-desktop-block">
#                        <div data-js="GlobalLogin">
#                         <div class="loggedIn GlobalLogin_pnl_LoggedIn" style="display: none">
#                          <p>
#                           You are already logged in as .
#                          </p>
#                          <a class="button buttonLarge buttonLock" href="javascript:__doPostBack('ctl00$HeaderPlaceholder$T22B85045062$globalLogin$lnk_Logout','')" id="HeaderPlaceholder_T22B85045062_globalLogin_lnk_Logout">
#                           Logout
#                          </a>
#                         </div>
#                         <div class="loggedOut GlobalLogin_pnl_LoggedOut" style="display: none">
#                          <h2 class="offScreen">
#                           Login
#                          </h2>
#                          <div>
#                           <div id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget">
#                            <fieldset id="sfLoginWidgetWrp">
#                             <div id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_loginWidgetPanel">
#                              <ol class="sfLoginFieldsWrp">
#                               <li accesskey="u" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName">
#                                <div>
#                                 <label class="sfTxtLbl sfInlineBlock" for="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_textBox_write" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_titleLabel_write">
#                                  Email / Username
#                                 </label>
#                                </div>
#                                <a class="sfOptionalExpander" href="javascript:__doPostBack('ctl00$HeaderPlaceholder$T22B85045062$globalLogin$loginWidget$ctl00$ctl00$UserName$ctl00$ctl00$expandButton_write','')" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_expandButton_write" onclick="return false;" style="display:none;">
#                                 Click to add
#                                </a>
#                                <div class="sfFieldWrp" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_expandableTarget_write" style="display:;">
#                                 <input class="sfTxt" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_textBox_write" name="ctl00$HeaderPlaceholder$T22B85045062$globalLogin$loginWidget$ctl00$ctl00$UserName$ctl00$ctl00$textBox_write" type="text"/>
#                                 <p class="sfExample" id="HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_characterCounterDescription_write" style="display:none;">
#                                 </p>
#                                </div>
# ...
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Web.UI.Extenders.ExpandableExtender, {"expandElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_expandButton_write"),"expandTarget":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_expandableTarget_write"),"expandText":"Click to add","expanded":true}, null, {"fieldControl":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName"}, $get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName"));
#     $create(Telerik.Sitefinity.Web.UI.Fields.TextField, {"_allowNulls":false,"_conditionalTemplatesContainerId":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ConditionalTemplates","_currentCondition":"displaymode-equal-write","_maxChars":0,"_readOnlyReplacement":null,"_textBoxId":"textBox_write","_textLabelId":"textLabel_read","_trimSpaces":false,"_unit":null,"conditionDictionary":{"displaymode-equal-read":"ClientTemplatePanel_UserName","displaymode-equal-write":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_conditionalTemplate"},"controlErrorCssClass":null,"dataFieldName":null,"dataFormatString":null,"defaultValue":"","description":null,"descriptionElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_descriptionLabel_write"),"displayMode":1,"example":null,"exampleElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_exampleLabel_write"),"fieldName":null,"suffix":"_UserName","textBoxElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_textBox_write"),"title":"Email / Username","titleElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName_ctl00_ctl00_titleLabel_write"),"validatorDefinition":"{\"AlphaNumericViolationMessage\":\"Non alphanumeric characters are not allowed.\",\"ComparingValidatorDefinitions\":[],\"CurrencyViolationMessage\":\"You have entered an invalid currency.\",\"EmailAddressViolationMessage\":\"You have entered an invalid email address.\",\"ExpectedFormat\":0,\"IntegerViolationMessage\":\"You have entered an invalid integer.\",\"InternetUrlViolationMessage\":\"You have entered an invalid URL.\",\"MaxLength\":0,\"MaxLengthViolationMessage\":\"Too long\",\"MaxValue\":null,\"MaxValueViolationMessage\":\"Too big\",\"MessageCssClass\":\"sfError\",\"MessageTagName\":\"div\",\"MinLength\":0,\"MinLengthViolationMessage\":\"Too short.\",\"MinValue\":null,\"MinValueViolationMessage\":\"Too small.\",\"NonAlphaNumericViolationMessage\":\"Alphanumeric characters are not allowed.\",\"NumericViolationMessage\":\"You have entered an invalid number.\",\"PercentageViolationMessage\":\"You have entered an invalid percentage.\",\"RegularExpression\":null,\"RegularExpressionSeparator\":null,\"RegularExpressionViolationMessage\":\"Invalid format\",\"Required\":true,\"RequiredViolationMessage\":\"Enter your email \\/ username\",\"ResourceClassId\":\"\",\"USSocialSecurityNumberViolationMessage\":\"You have entered an invalid US social security number.\",\"USZipCodeViolationMessage\":\"You have entered an invalid US ZIP code.\",\"ValidateIfInvisible\":true}","value":""}, null, null, $get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_UserName"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Web.UI.Extenders.ExpandableExtender, {"expandElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_expandButton_write"),"expandTarget":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_expandableTarget_write"),"expandText":"Click to add","expanded":true}, null, {"fieldControl":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password"}, $get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password"));
#     $create(Telerik.Sitefinity.Web.UI.Fields.TextField, {"_allowNulls":false,"_conditionalTemplatesContainerId":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ConditionalTemplates","_currentCondition":"displaymode-equal-write","_maxChars":0,"_readOnlyReplacement":null,"_textBoxId":"textBox_write","_textLabelId":"textLabel_read","_trimSpaces":false,"_unit":null,"conditionDictionary":{"displaymode-equal-read":"ClientTemplatePanel_Password","displaymode-equal-write":"HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_conditionalTemplate"},"controlErrorCssClass":null,"dataFieldName":null,"dataFormatString":null,"defaultValue":"","description":null,"descriptionElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_descriptionLabel_write"),"displayMode":1,"example":null,"exampleElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_exampleLabel_write"),"fieldName":null,"suffix":"_Password","textBoxElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_textBox_write"),"title":"Password","titleElement":$get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password_ctl00_ctl00_titleLabel_write"),"validatorDefinition":"{\"AlphaNumericViolationMessage\":\"Non alphanumeric characters are not allowed.\",\"ComparingValidatorDefinitions\":[],\"CurrencyViolationMessage\":\"You have entered an invalid currency.\",\"EmailAddressViolationMessage\":\"You have entered an invalid email address.\",\"ExpectedFormat\":0,\"IntegerViolationMessage\":\"You have entered an invalid integer.\",\"InternetUrlViolationMessage\":\"You have entered an invalid URL.\",\"MaxLength\":0,\"MaxLengthViolationMessage\":\"Too long\",\"MaxValue\":null,\"MaxValueViolationMessage\":\"Too big\",\"MessageCssClass\":\"sfError\",\"MessageTagName\":\"div\",\"MinLength\":0,\"MinLengthViolationMessage\":\"Too short.\",\"MinValue\":null,\"MinValueViolationMessage\":\"Too small.\",\"NonAlphaNumericViolationMessage\":\"Alphanumeric characters are not allowed.\",\"NumericViolationMessage\":\"You have entered an invalid number.\",\"PercentageViolationMessage\":\"You have entered an invalid percentage.\",\"RegularExpression\":null,\"RegularExpressionSeparator\":null,\"RegularExpressionViolationMessage\":\"Invalid format\",\"Required\":true,\"RequiredViolationMessage\":\"Enter your password\",\"ResourceClassId\":\"\",\"USSocialSecurityNumberViolationMessage\":\"You have entered an invalid US social security number.\",\"USZipCodeViolationMessage\":\"You have entered an invalid US ZIP code.\",\"ValidateIfInvisible\":true}","value":""}, null, null, $get("HeaderPlaceholder_T22B85045062_globalLogin_loginWidget_ctl00_ctl00_Password"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Web.UI.RadMenu, {"_childListElementCssClass":null,"_selectedItemIndex":"1:4","_selectedValue":"Online forums","_skin":"Default","clientStateFieldID":"ctl00_HeaderPlaceholder_T22B85045022_ctl00_ctl00_siteMapControl_horizontaldropdownmenu_ClientState","collapseAnimation":"{\"duration\":450}","expandAnimation":"{\"duration\":450}","itemData":[{"attributes":{"Sitefinity.PageGUID":"0847D232-4371-4795-A5DE-A6D4DC7DDA7D"},"value":"Home","navigateUrl":"~/home"},{"attributes":{"Sitefinity.PageGUID":"C81C9BCC-2FE3-4FCF-99E9-4B5339D7644F"},"items":[{"attributes":{"Sitefinity.PageGUID":"522FBD98-7C10-4ACD-8EAA-767A4BD6C3C5"},"value":"Get immediate support","navigateUrl":"~/get-support/get-immediate-support"},{"attributes":{"Sitefinity.PageGUID":"C3D5B9A9-F371-61BC-846E-FF0000E9D3FC"},"items":[{"attributes":{"Sitefinity.PageGUID":"29444BAA-F371-61BC-846E-FF0000E9D3FC"},"value":"Getting support – how much does it cost?","navigateUrl":"~/get-support/who-can-assist/getting-support-how-much-does-it-cost"}],"value":"Who can assist","navigateUrl":"~/get-support/who-can-assist"},{"attributes":{"Sitefinity.PageGUID":"7C8823AA-F371-61BC-846E-FF0000E9D3FC"},"value":"Find a professional","navigateUrl":"~/get-support/find-a-professional"},{"attributes":{"Sitefinity.PageGUID":"0C42C3A9-F371-61BC-846E-FF0000E9D3FC"},"value":"National help lines and websites","navigateUrl":"~/get-support/national-help-lines-and-websites"},{"attributes":{"Sitefinity.PageGUID":"69478FED-F42C-4FAA-8005-D4F28E20C179"},"items":[{"attributes":{"Sitefinity.PageGUID":"8795ADCE-EF60-4C8D-9142-0607A7EB45F0"},"value":"Sign up","navigateUrl":"~/get-support/online-forums/sign-up"},{"attributes":{"Sitefinity.PageGUID":"CEA6FFA9-F371-61BC-846E-FF0000E9D3FC"},"value":"Login","navigateUrl":"~/get-support/online-forums/login"},{"attributes":{"Sitefinity.PageGUID":"7DFEC9A9-F371-61BC-846E-FF0000E9D3FC"},"value":"Community rules","navigateUrl":"~/get-support/online-forums/community-rules"}],"value":"Online forums","selected":true,"navigateUrl":"~/get-support/online-forums","cssClass":"rmSelected"},{"attributes":{"Sitefinity.PageGUID":"6E9157E1-AAAD-4E59-A320-2B80343838E0"},"value":"Treatment options","navigateUrl":"~/get-support/treatment-options"},{"attributes":{"Sitefinity.PageGUID":"CD7ED9A9-F371-61BC-846E-FF0000E9D3FC"},"items":[{"attributes":{"Sitefinity.PageGUID":"C1C3E4A9-F371-61BC-846E-FF0000E9D3FC"},"value":"Contact a NewAccess coach","navigateUrl":"~/get-support/newaccess/where-are-your-access-coaches-located"},{"attributes":{"Sitefinity.PageGUID":"5D6BD9A9-F371-61BC-846E-FF0000E9D3FC"},"value":"Background to NewAccess","navigateUrl":"~/get-support/newaccess/background-to-newaccess"},{"attributes":{"Sitefinity.PageGUID":"4DE231AA-F371-61BC-846E-FF0000E9D3FC"},"value":"NewAccess testimonials","navigateUrl":"~/get-support/newaccess/newaccess-testimonials"},{"attributes":{"Sitefinity.PageGUID":"4AE431AA-F371-61BC-846E-FF0000E9D3FC"},"value":"NewAccess-Frequently Asked Questions","navigateUrl":"~/get-support/newaccess/faqs"},{"attributes":{"Sitefinity.PageGUID":"7AACD2A9-F371-61BC-846E-FF0000E9D3FC"},"value":"NewAccess Information for PHNs and Service Providers","navigateUrl":"~/get-support/newaccess/why-newaccess"},{"attributes":{"Sitefinity.PageGUID":"951733AA-F371-61BC-846E-FF0000E9D3FC"},"value":"NewAccess in PHNs: Critical success features","navigateUrl":"~/get-support/newaccess/newaccess-in-phns-critical-success-features"}],"value":"NewAccess – Coaching you through tough times","navigateUrl":"~/get-support/newaccess"},{"attributes":{"Sitefinity.PageGUID":"F9DDF9A9-F371-61BC-846E-FF0000E9D3FC"},"items":[{"attributes":{"Sitefinity.PageGUID":"9400FAA9-F371-61BC-846E-FF0000E9D3FC"},"value":"What to say and why","navigateUrl":"~/get-support/have-the-conversation/what-to-say-and-why"},{"attributes":{"Sitefinity.PageGUID":"C102FAA9-F371-61BC-846E-FF0000E9D3FC"},"value":"Talk about it","navigateUrl":"~/get-support/have-the-conversation/talk-about-it"},{"attributes":{ ...
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Forums.Web.UI.PostsListView, {"_saveTitleChangesButtonId":"MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_saveTitleChangesBtn","_showEditBoxButtonId":"MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_showEditBoxButton","_threadTitleEditBoxId":"MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_threadTitleEditBox","threadTitle":null}, null, null, $get("MainContentPlaceholder_C006_forumsFrontendPostsList"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Web.UI.RadListView, {"UniqueID":"ctl00$MainContentPlaceholder$C006$forumsFrontendPostsList$ctl00$ctl00$list","_clientSettings":{"DataBinding":{"ItemPlaceHolderID":"ctl00_MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_list_ItemsContainer","DataService":{}}},"_virtualItemCount":30,"clientStateFieldID":"ctl00_MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_list_ClientState","renderMode":1}, null, null, $get("ctl00_MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_list"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Forums.Web.UI.PostsDetailsView, {"_defaultQuoteText":"Your quote goes here","_openPostForm":"false","_successfullySubmitted":"false","baseUrl":"/","cancelButton":$get("MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_postsDetailsView_ctl00_ctl00_cancelBtn"),"cancelPostUrl":"/get-support/online-forums/depression/depression-fight-it-or-embrace-it-","closePostsDetailsView":$get("MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_postsDetailsView_ctl00_ctl00_closePostsDetailsView"),"onLoadEvents":[],"quoteButton":$get("MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_postsDetailsView_ctl00_ctl00_quoteBtn")}, null, null, $get("MainContentPlaceholder_C006_forumsFrontendPostsList_ctl00_ctl00_postsDetailsView"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Web.UI.UserPreferences, {"_timeOffset":"36000000","_userBrowserSettingsForCalculatingDates":true,"timeZoneDisplayName":"(UTC+10:00) Brisbane","timeZoneId":"E. Australia Standard Time"}, null, null);
# });
# //]]>
#    </script>
#   </form>
#   <!-- The Websilk javascript -->
#   <script src="/App_Themes/standard/scripts/libs/knockout-3.2.0.js?v=20150521" type="text/javascript">
#   </script>
#   <script src="/App_Themes/Standard/scripts/libs/knockout.mapping-latest.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/Standard/scripts/libs/knockout.validation.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/Standard/Scripts/libs/knockout.simpleGrid.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/Standard/scripts/knockoutModels.js?v=20150521" type="text/javascript">
#   </script>
#   <script src="/App_Themes/global/scripts/moment.min.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/global/scripts/url.min.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/global/scripts/linq.min.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/global/scripts/jquery.linq.min.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/reskin/scripts/jquery.flexslider.2.2.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/standard/scripts/plugins.js?v=20150427" type="text/javascript">
#   </script>
#   <script src="/App_Themes/reskin/scripts/main.js" type="text/javascript">
#   </script>
#   <script src="/App_Themes/global/scripts/global.js?v=20150427" type="text/javascript">
#   </script>
#   <script src="/Websilk/Search/Controls/facetedsearch.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var ytTID = null;
#         // BB - deferred activation of iframes, but only if they set data-src attribute to target url
#         $(function () {
#             processDeferredIframes();
#         });
#
#         function processDeferredIframes() {
#             var deferIframes = $('iframe[data-src]');
#
#             // set the src attribute to activate the video
#             deferIframes.each(function () {
#                 $(this).attr('src', $(this).attr('data-src'));
#             });
#
#             if ((deferIframes.length > 0) && (ytTID == null)) {
#                 // kick off interval check for YT API
#                 ytTID = setInterval(handleYouTubeApiLinking, 250);
#             }
#         }
#
#         function handleYouTubeApiLinking() {
#             if (typeof onYouTubeIframeAPIReady === 'function') {
#                 // stop interval
#                 clearInterval(ytTID);
#                 ytTID = null;
#
#                 // attach API to video iframes
#                 onYouTubeIframeAPIReady();
#             }
#         }
#   </script>
#  </body>
# </html>

# %%
#Function to extract date
def extract_age_from_result(soup):
    age = []
    for div in soup.find_all(name="div", attrs={"class":"media"}):
        for div in div.find_all(name="div", attrs={"class":"sfforumPostAge"}):
            age.append(div["sfforumPostAge"])
    return(age)

# %%
#Function to extract author
def extract_author_from_result(soup):
    authors = []
    for div in soup.find_all(name="div", attrs={"class":"media"}):
        for span in div.find_all(name="span", attrs={"class":"sfforumUser"}):
            authors.append(span["sfforumUser"])
    return(authors)

# %%
#Function to extract badge title
def extract_badge_from_result(soup):
    badges = []
    for div in soup.find_all(name="div", attrs={"class":"media"}):
        for div in div.find_all(name="div", attrs={"class":"badgeTitle"}):
            badges.append(div["badgeTitle"])
    return(badges)

# %%
#Function to extract like counter
def extract_likes_from_result(soup): 
    likes = []
    for div in soup.find_all(name="div", attrs={"class":"media"}):
        for span in div.find_all(name="span", attrs={"class":"likeCounter"}):
            likes.append(span["likeCounter"])
    return(likes)

# %%
#Function to extract post content
def extract_comments_from_result(soup): 
    comments = []
    for div in soup.find_all(name="div", attrs={"class":"media"}):
        for div in div.find_all(name="div", attrs={"class":"sfContentBlock"}):
            comments.append(div["sfContentBlock"])
    return(comments)

# %%
header=["date","author","badge","likes","content"]
postings=pd.DataFrame(columns=header)

# for field in soup:
#     #items['date'] = soup.find_all("span",{"class": "date"}) #extract date
    
#     items['job_title'] = extract_job_title_from_result(soup) # extract job title
#     items['company'] = extract_company_from_result(soup) # extract company
#     items['location'] = extract_location_from_result(soup) # extract location
#     items['salary'] = extract_salary_from_result(soup) # extract salary
#     items['description'] = extract_summary_from_result(soup) # extract job description
print(postings)
# Out:
# Empty DataFrame
# Columns: [date, author, badge, likes, content]
# Index: []

# %%
import regex as re
#scraping code:
record_max = 6 # # of pages scraped
step = 1
for start in range(1,record_max,step):
    url = "https://www.beyondblue.org.au/get-support/online-forums/depression/depression-fight-it-or-embrace-it-/page/"+ str(start)
    time.sleep(2)
    # You can use status codes to understand how the target server responds to your request.
    #Ex. 200 = OK, 400 = Bad Request, 403 = Forbidden, 404 = Not Found
    print('Status Code: ',response.status_code, start)
    response = requests.get(url)
    #specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
    soup = BeautifulSoup(response.text, "lxml")
    for li in soup.find_all(name="li", attrs={"class":"sfforumThreadPost"}):
        #specifying row num for index of job posting in dataframe
        num = (len(postings) + 1) 
        #creating an empty list to hold the data for each posting
        posting = []
        a = li.find(name="div", attrs={"class":"sfforumPostAge"}) # grab posting date
        posting_date = re.findall(r"[\d]{1,2}\s[A-Z|a-z]*\s[\d]{4}", a.text)
        posting.append(posting_date)
        b = li.find(name="span", attrs={"class":"sfforumUser"}) # grab user
        posting.append(b.text.strip())
        c = li.find(name="div", attrs={"class":"badgeTitle"}) # grab badge title
        if not c:
            posting.append("No Badge") # for new user with no badge
        else:
            posting.append(c.text.strip())
        d = li.find(name="span", attrs={"class":"likeCounter"}) # grab like counter
        posting.append(d.text.strip())
        e = li.find(name="div", attrs={"class":"sfContentBlock"}) # grab comments
        posting.append(e.text.strip())
        postings.loc[num] = posting #appending list of job post info to dataframe at index num

print("Scraping complete")
# Out:
# Status Code:  200 1
# Status Code:  200 2
# Status Code:  200 3
# Status Code:  200 4
# Status Code:  200 5
# Scraping complete

# %%
postings
# Out:
#                 date        author               badge likes  \
# 1     [3 March 2018]       Doolhof  Community Champion     4
# 2     [3 March 2018]   quirkywords  Community Champion     3
# 3     [3 March 2018]   Summer Rose  Valued Contributor     2
# 4     [4 March 2018]       Doolhof  Community Champion     2
# 5     [4 March 2018]       Doolhof  Community Champion     3
# 6     [4 March 2018]  demonblaster  Valued Contributor
# 7     [4 March 2018]  demonblaster  Valued Contributor
# 8     [4 March 2018]       Doolhof  Community Champion     1
# 9     [4 March 2018]  demonblaster  Valued Contributor
# 10    [5 March 2018]       Doolhof  Community Champion     1
# 11    [5 March 2018]  Shelley anne            No Badge     1
# 12    [5 March 2018]  demonblaster  Valued Contributor
# 13    [5 March 2018]       Quercus  Community Champion     2
# 14    [5 March 2018]       Doolhof  Community Champion     3
# 15    [5 March 2018]       PamelaR  Community Champion     2
# 16    [5 March 2018]    White Rose  Community Champion     2
# 17    [5 March 2018]       Doolhof  Community Champion     2
# 18    [5 March 2018]       Doolhof  Community Champion     2
# 19    [5 March 2018]       PamelaR  Community Champion     2
# 20    [5 March 2018]       Quercus  Community Champion     1
# 21    [5 March 2018]  demonblaster  Valued Contributor     1
# 22    [5 March 2018]   Summer Rose  Valued Contributor     3
# 23    [5 March 2018]      blondguy  Community Champion     3
# 24    [5 March 2018]  demonblaster  Valued Contributor     1
# 25    [6 March 2018]       Doolhof  Community Champion     4
# 26    [6 March 2018]        Ggrand   blueVoices member     1
# 27    [6 March 2018]  white knight  Community Champion     1
# 28    [6 March 2018]       Doolhof  Community Champion     1
# 29    [6 March 2018]  white knight  Community Champion     2
# 30    [6 March 2018]  demonblaster  Valued Contributor     1
# ..               ...           ...                 ...   ...
# 121  [11 April 2018]       PamelaR  Community Champion     1
# 122  [12 April 2018]       Doolhof  Community Champion     1
# 123  [12 April 2018]  demonblaster  Valued Contributor
# 124  [12 April 2018]       PamelaR  Community Champion     1
# 125  [12 April 2018]       Doolhof  Community Champion     1
# 126  [12 April 2018]  demonblaster  Valued Contributor
# 127  [12 April 2018]       PamelaR  Community Champion     1
# 128  [12 April 2018]       Chloe_M  Valued Contributor     1
# 129  [12 April 2018]  demonblaster  Valued Contributor     1
# 130  [12 April 2018]      blondguy  Community Champion     1
# 131  [13 April 2018]       Doolhof  Community Champion     1
# 132  [13 April 2018]       Doolhof  Community Champion     1
# 133  [13 April 2018]       Chloe_M  Valued Contributor     1
# 134  [13 April 2018]       PamelaR  Community Champion     1
# 135  [14 April 2018]       Doolhof  Community Champion     2
# 136  [14 April 2018]       Chloe_M  Valued Contributor     1
# 137  [14 April 2018]        Ggrand   blueVoices member     1
# 138  [14 April 2018]       Doolhof  Community Champion     1
# 139  [14 April 2018]       Doolhof  Community Champion     1
# 140  [14 April 2018]       Chloe_M  Valued Contributor     1
# 141  [15 April 2018]       Doolhof  Community Champion
# 142  [15 April 2018]       Chloe_M  Valued Contributor     1
# 143  [15 April 2018]        Ggrand   blueVoices member
# 144  [15 April 2018]       Chloe_M  Valued Contributor     1
# 145  [16 April 2018]       Doolhof  Community Champion
# 146  [16 April 2018]       Chloe_M  Valued Contributor
# 147  [16 April 2018]       Doolhof  Community Champion     1
# 148  [16 April 2018]       Chloe_M  Valued Contributor     1
# 149  [16 April 2018]        Ggrand   blueVoices member
# 150  [16 April 2018]       Chloe_M  Valued Contributor
#
#                                                content
# 1    Right now I feel like I don't have the energy ...
# 2    Mrs dool.\nI am sending you a big reassuring h...
# 3    Hi Doolhof\nI'm sorry that you feel so low.  Y...
# 4    Hi Quirky,\nThanks for the virtual hug, I need...
# 5    Hi Summer Rose,\nThanks for your encouragement...
# 6    Dools so sorry to hear you're in deep darl.\nI...
# 7    Dear Dools how are you feeling today darl 🤗\nI...
# 8    Dear DB,\nThank you so very much. I have been ...
# 9    Hi all \nYeah it does pull us under its so dam...
# 10   Hi DB,\nWoke up this morning wondering why I h...
# 11   Ah Mrs D, so sorry you are hurting. Here is a ...
# 12   Ahh Dools 🤗 how awful how you're feeling. Feel...
# 13   Hi Mrs D, \nI'm relieved you asked for help. I...
# 14   Dear Nat, DB and Shell,\nI have tears of grati...
# 15   Hi Dools\nAwwww, sending you loads of virtual ...
# 16   Dear Bev\nI would give anything to have the wo...
# 17   Hi PamelaR,\nThanks for your message. I have b...
# 18   Hi Mary,\nThanks so much for your very kind wo...
# 19   Hello Dools\nMemory caught up with me.... no i...
# 20   Hi Mrs D (and a wave to everyone else of cours...
# 21   So many beautiful people 🤗\nI imagined once a ...
# 22   Hi Doolhof\nI've been offline awhile and just ...
# 23   Hello Dools\nI really hope you have relief soo...
# 24   Beautifully said Rose \nThe stars ... oh yeah ...
# 25   Dear precious people,\nThank you so very much ...
# 26   Hell Dools,\nYou are so loved and you have a p...
# 27   Hi Mrs Dools\nI have not much to say. So I tho...
# 28   Hi Karen,\nThank you so very much for your ver...
# 29   Thankyou Mrs Dools\nPainting?  Well a coincide...
# 30   Yeah.. the walls go up in a second. Its like t...
# ..                                                 ...
# 121  Fantastic Dools. What a great day! You've achi...
# 122  Hi Chloe, Karen, Pamela and Everyone,\nThank y...
# 123  Hey Doolsy and all \n\r\nFinally got here, I'v...
# 124  LOL Dools, a snarling German Shepherd doesn't ...
# 125  Hi All,\nI enjoyed a walk in the park before t...
# 126  lol Doolsy you've got a wicked sense of humour...
# 127  I'm sitting here with tears running down my fa...
# 128  hi demonblaster, hello again Pammy, hey Dools\...
# 129  You poor thing having that big cry although I ...
# 130  Hi Dools\nThankyou for the super kind post :-)...
# 131  Hey Paul, Mate,\nHI. Please know I have not ta...
# 132  Hi Chloe, Pammy, DB, Paul and All reading,\nTh...
# 133  Hi Dools,\nThat lady at the Op Shop sounds lov...
# 134  Hello Dools (wave to everyone else)\nPlease do...
# 135  Hi Chloe, PamelaR and All,\nIt does seem to he...
# 136  Hi Dools,\nOnce again, your imaginative mind m...
# 137  Hello Dools, and everyone else.\nThe upside do...
# 138  Hi Chloe,\nIt is a bit of a journey to get to ...
# 139  Hey Grandy,\nThanks. I am going to try to make...
# 140  Hi Dools,\nmaybe you could leave your cat and ...
# 141  Hi Chloe,\nThanks. I am going to try to make p...
# 142  Hey Dools,\nthats good that you are going. I a...
# 143  Hello Dools,\nIm just popping in to wish you a...
# 144  Hey Grandy,\nI am very relived that nana is wi...
# 145  Hi Chloe,\nLast night I saw the fires on the n...
# 146  Hi Dools,\nyes the fires are pretty bad, the w...
# 147  Hi Chloe,\nI hope all goes well with catching ...
# 148  Hi Dools,\nThis morning was ok. we got a lot d...
# 149  Hello Dools , Chloe,\nDools I hope you enjoy t...
# 150  Hugs are special, especially tight ones that m...
#
# [150 rows x 5 columns]

# %%
postings.to_excel("postings.xlsx") # Write scraped results to file

# %% [markdown]
# # [See /Gopinaath/capstone-eda.ipynb for continuation with EDA](./capstone-eda.ipynb)
